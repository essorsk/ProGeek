# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
from bs4 import BeautifulSoup as bs
import re
import requests

import warnings
warnings.filterwarnings('ignore')

# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline

# %% [markdown]
# ### Парсинг вакансий с hh.ru

# %%
#Задаем параметры поиска
vacancy_name = 'data scientist'
search_depth = 6 #количество страниц поиска
analysis_period = 15 #дни публикаций
#area = 1(Moscow), 4(Novosibirsk),1001(Other countries)

# %%
#Получаем ссылку для выполнения поиска
hh_url = 'https://hh.ru/search/vacancy?search_period='+str(analysis_period)+'&text='+vacancy_name+'&area=1&area=4&area=1001'
hh_url
# Out:
# 'https://hh.ru/search/vacancy?search_period=15&text=data scientist&area=1&area=4&area=1001'

# %%
#Обход блокировки hh.ru от автоматического парсинга
headers = {'accept': '*/*',
           'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/12.1.1 Safari/605.1.15'}

session = requests.session()

# %%
n = 0
titles = []
employer = []
address = []
salarys = []
hrefs = []
description = []
requir = []

while n < search_depth:
    request = session.get(hh_url+'&page='+str(n), headers=headers)
    
    hh_html = bs(request.content, 'html.parser')
    divs = hh_html.find_all('div', attrs={'data-qa': 'vacancy-serp__vacancy'})

    for div in divs:
        title = div.find('a', attrs={'data-qa': 'vacancy-serp__vacancy-title'}).text
        company = div.find('a', attrs={'data-qa': 'vacancy-serp__vacancy-employer'}).text
        place = div.find('span', attrs={'data-qa': 'vacancy-serp__vacancy-address'}).text
        city = (re.findall('[а-яА-Я]+', place))[0]
        salary = div.find('div', attrs={'data-qa': 'vacancy-serp__vacancy-compensation'})
        responsibility = div.find('div', attrs={'data-qa': 'vacancy-serp__vacancy_snippet_responsibility'}).text
        requirment = div.find('div', attrs={'data-qa': 'vacancy-serp__vacancy_snippet_requirement'}).text

        if salary == None:
            salary = 'Не указанно'
        else:
            salary = div.find('div', attrs={'data-qa': 'vacancy-serp__vacancy-compensation'}).text
        
        href = div.find('a', attrs={'data-qa': 'vacancy-serp__vacancy-title'})['href']
        
        titles.append(title)
        employer.append(company)
        salarys.append(salary)
        address.append(city)
        hrefs.append(href)
        description.append(responsibility)
        requir.append(requirment)
        
        #print(f'Вакансия: {title} в {company}\nПредлагаемая зарплата: {salary}\nСсылка: {href}\n{place}')
        #print(f'{responsibility}\n{requirment}\n\n')
        #print(city)
    
    n += 1

# %%
#Данные зальем в датафрейм
df = pd.DataFrame({'Title': titles,
                   'Company': employer,
                   'Salary': salarys,
                   'Address': address,
                   'Description': description,
                   'Requirments': requir,
                   'Href': hrefs}, columns=['Title','Company', 'Salary','Address','Description','Requirments', 'Href'])

df.replace(u'\xa0',u'', regex=True, inplace=True)
df.head()
# Out:
#                                                Title  \
# 0                    Data Scientist (Кипр, Лимассол)
# 1  Главный аналитик-математик (Data Analyst / Dat...
# 2                                     Data scientist
# 3                                     Data scientist
# 4              Senior Data Scientist (Академгородок)
#
#                                   Company              Salary      Address  \
# 0   Кадровое агентство Алексея Сухорукова       3500-5000 EUR  Новосибирск
# 1                                 Связной  180000-230000 руб.       Москва
# 2                      Свордфиш Секьюрити      от 150000 руб.       Москва
# 3                                  Билайн         Не указанно       Москва
# 4                          ООО ЭЛСИ ГРУПП  100000-200000 руб.  Новосибирск
#
#                                          Description  \
# 0  Работа с большими объемами структурированных и...
# 1  Исследование данных методами математической ст...
# 2  Извлечение данных из нескольких информационный...
# 3  Под руководством Senior Data Scientist и совме...
# 4  Распознавание образов в видеопотоке. Улучшение...
#
#                                          Requirments  \
# 0  Опыт разработки масштабируемых математических ...
# 1  Хорошее владение языком R (предпочтительно) ил...
# 2  Hadoop как плюс. Postrgre SQL MySQL. Java как ...
# 3  Знание основных видов математических моделей и...
# 4  Понимание статистики и теории вероятностей, ум...
#
#                                                 Href
# 0  https://novosibirsk.hh.ru/vacancy/32375692?que...
# 1  https://novosibirsk.hh.ru/vacancy/30250856?que...
# 2  https://novosibirsk.hh.ru/vacancy/32586327?que...
# 3  https://novosibirsk.hh.ru/vacancy/32667835?que...
# 4  https://novosibirsk.hh.ru/vacancy/29701878?que...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 7 columns):
# Title          118 non-null object
# Company        118 non-null object
# Salary         118 non-null object
# Address        118 non-null object
# Description    118 non-null object
# Requirments    118 non-null object
# Href           118 non-null object
# dtypes: object(7)
# memory usage: 6.5+ KB

# %%
df['Address'].unique()
# Out:
# array(['Новосибирск', 'Москва', 'Финляндия'], dtype=object)

# %%
#df.groupby('Salary', as_index=False).size()

# %% [markdown]
# rcParams['figure.figsize'] = 8, 3
# df.groupby('Salary', as_index=True).size().plot(kind='bar', title='График количества вакансий и зарплаты')

# %%
#Выгрузка базы в файл
writer = pd.ExcelWriter('ds.xlsx')
df.to_excel(writer, 'Сведения по вакансии')
writer.save()

# %%
#Выборка определенного города
nsk = df.loc[(df['Address']=='Новосибирск'),:]
nsk
# Out:
#                                              Title  \
# 0                  Data Scientist (Кипр, Лимассол)
# 4            Senior Data Scientist (Академгородок)
# 7                                   Data scientist
# 11                  Data Scientist (Академгородок)
# 15                                  Data Scientist
# 74   Специалист по анализу данных (Data Scientist)
# 84                                  Data scientist
# 105               Data Scientist (Санкт-Петербург)
#
#                                     Company              Salary      Address  \
# 0     Кадровое агентство Алексея Сухорукова       3500-5000 EUR  Новосибирск
# 4                            ООО ЭЛСИ ГРУПП  100000-200000 руб.  Новосибирск
# 7               Центр финансовых технологий         Не указанно  Новосибирск
# 11                           ООО ЭЛСИ ГРУПП         Не указанно  Новосибирск
# 15    Кадровое агентство Алексея Сухорукова   80000-200000 руб.  Новосибирск
# 74                                   Auriga         Не указанно  Новосибирск
# 84                             ООО ВилайнТв       от 70000 руб.  Новосибирск
# 105                   ЦРТ | Группа компаний         Не указанно  Новосибирск
#
#                                            Description  \
# 0    Работа с большими объемами структурированных и...
# 4    Распознавание образов в видеопотоке. Улучшение...
# 7    Прогнозирование спроса. Идентификация пользова...
# 11   Системы кредитного скоринга для различных стра...
# 15   Анализ поведения клиентов для решения задач ма...
# 74   Создание (в команде) новых сценариев использов...
# 84   Умеете систематизировать полученную информацию...
# 105  Разработка алгоритмов распознавания речи/ эмоц...
#
#                                            Requirments  \
# 0    Опыт разработки масштабируемых математических ...
# 4    Понимание статистики и теории вероятностей, ум...
# 7    Опыт работы с данными в проектах, желательно п...
# 11   Хорошая математическая подготовка, знание осно...
# 15   Опыт в коммерческих/не коммерческих проектах п...
# 74   Уверенное знание инструментов статистического ...
# 84   Умеете читать и интерпретировать данные. Имеет...
# 105  Хорошая математическая подготовка (знание мето...
#
#                                                   Href
# 0    https://novosibirsk.hh.ru/vacancy/32375692?que...
# 4    https://novosibirsk.hh.ru/vacancy/29701878?que...
# 7    https://novosibirsk.hh.ru/vacancy/30318660?que...
# 11   https://novosibirsk.hh.ru/vacancy/31150346?que...
# 15   https://novosibirsk.hh.ru/vacancy/31812383?que...
# 74   https://novosibirsk.hh.ru/vacancy/32591451?que...
# 84   https://novosibirsk.hh.ru/vacancy/31106608?que...
# 105  https://novosibirsk.hh.ru/vacancy/22856468?que...
